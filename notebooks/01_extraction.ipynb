# %% [markdown]
# # Data Extraction - Airbnb Dataset
#
# ## Objective
# Load the raw Airbnb dataset and perform initial inspection to understand its structure, size, and basic characteristics.

# %%
import pandas as pd
import numpy as np

# %%
file_path = "/content/airbnb_listing.csv"

df = pd.read_csv(file_path)
df.head()
# Out:
# /tmp/ipykernel_13062/4240784688.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#    calculated_host_listings_count_private_rooms host_response_rate  \
# 0                                           0.0                NaN
# 1                                           0.0                NaN
# 2                                           1.0                NaN
# 3                                           0.0                NaN
# 4                                           0.0                NaN
#
#    host_total_listings_count  review_scores_accuracy license  \
# 0                        NaN                    3.44     NaN
# 1                        NaN                    4.88     NaN
# 2                        NaN                    4.61     NaN
# 3                        NaN                     NaN     NaN
# 4                        NaN                    4.83     NaN
#
# ...

# %%
df.shape
# Out:
# (42903, 79)

# %%
df.columns.tolist()
# Out:
# ['calculated_host_listings_count_private_rooms',
#  'host_response_rate',
#  'host_total_listings_count',
#  'review_scores_accuracy',
#  'license',
#  'calendar_last_scraped',
#  'picture_url',
#  'host_has_profile_pic',
#  'minimum_maximum_nights',
#  'host_acceptance_rate',
#  'availability_90',
#  'last_scraped',
#  'neighbourhood_cleansed',
#  'last_review',
#  'availability_60',
#  'minimum_nights_avg_ntm',
#  'bedrooms',
#  'review_scores_cleanliness',
#  'host_response_time',
#  'reviews_per_month',
#  'listing_url',
#  'availability_eoy',
#  'amenities',
#  'calculated_host_listings_count_shared_rooms',
#  'host_listings_count',
#  'longitude',
#  'host_name',
#  'host_verifications',
#  'neighbourhood_group_cleansed',
#  'host_picture_url',
#  'room_type',
#  'minimum_minimum_nights',
#  'bathrooms',
#  'review_scores_rating',
#  'maximum_nights_avg_ntm',
#  'estimated_occupancy_l365d',
#  'estimated_revenue_l365d',
#  'calculated_host_listings_count',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42903 entries, 0 to 42902
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   calculated_host_listings_count_private_rooms  42902 non-null  float64
#  1   host_response_rate                            32294 non-null  object
#  2   host_total_listings_count                     42423 non-null  float64
#  3   review_scores_accuracy                        35783 non-null  float64
#  4   license                                       25768 non-null  object
#  5   calendar_last_scraped                         42902 non-null  object
#  6   picture_url                                   42903 non-null  object
#  7   host_has_profile_pic                          42876 non-null  object
#  8   minimum_maximum_nights                        42889 non-null  float64
# ...

# %%
df.describe()
# Out:
#        calculated_host_listings_count_private_rooms  \
# count                                  42902.000000
# mean                                       1.500000
# std                                        5.677706
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      193.000000
#
#        host_total_listings_count  review_scores_accuracy  \
# count               42423.000000            35783.000000
# mean                   34.426490                4.801078
# std                   164.378849                0.346241
# min                     0.000000                1.000000
# 25%                     1.000000                4.750000
# 50%                     4.000000                4.900000
# 75%                    16.000000                5.000000
# ...

# %%
# count missing values in each column

df.isnull().sum().sort_values(ascending=False)
# Out:
# neighbourhood_group_cleansed    42903
# calendar_updated                42903
# host_neighbourhood              26987
# neighborhood_overview           20792
# neighbourhood                   20792
#                                 ...
# host_id                             0
# name                                0
# host_url                            0
# scrape_id                           0
# id                                  0
# Length: 79, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Column Categorization
#
# ### 1. Target Variables (KPIs)
# - estimated_revenue_l365d
# - estimated_occupancy_l365d
#
# ### 2. Key Features for Analysis
# - room_type
# - price
# - accommodates
# - bedrooms, bathrooms, beds
# - amenities
# - neighbourhood_cleansed
# - host_is_superhost
#
# ### 3. Columns with High Missing Values
# - host_neighbourhood
# - neighborhood_overview
# - host_about
# - license
#
# ### 4. Columns to Drop (Completely Missing)
# - neighbourhood_group_cleansed
# - calendar_updated
#
# ### 5. Columns Requiring Type Conversion
# - price (object → float)
# - host_response_rate (% → float)
# - host_acceptance_rate (% → float)
# - date columns → datetime

# %% [markdown]
# ## Conclusion
#
# - Dataset contains 42,903 listings with 79 features
# - No duplicate rows found
# - Several columns have missing values, including some completely empty columns
# - Key variables for business problem identified
# - Data type inconsistencies observed in price and percentage fields
